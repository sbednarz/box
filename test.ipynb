# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-2,2)
y = np.sin(x)

plt.plot(x,y,'r-')

# %%
in9 = np.loadtxt('IN9.txt')

# %%
plt.plot(in9[:,0], in9[:,1])
plt.xlabel('m/z')
plt.ylabel(u'Sygnał')
plt.xlim(50,1000)
# Out:
# (50, 1000)

# %%
plt.xlabel('m/z')
plt.ylabel(u'Sygnał')
plt.xlim(10,800)
plt.stem(in9[:,0], in9[:,1], linefmt='r-', markerfmt=' ', basefmt="red")
plt.savefig('wykres.png', dpi=300)
